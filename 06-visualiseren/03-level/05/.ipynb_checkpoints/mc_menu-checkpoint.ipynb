# %% [markdown]
# # McPandas with Fries, Please

# %% [markdown]
# We installeren de pandas package.

# %%
import pandas as pd

# %% [markdown]
# We halen CSV file op.

# %%
df = pd.read_csv("mc_menu_final.csv")
df
# Out:
#      Unnamed: 0            Category  \
# 0             0           Breakfast
# 1             1           Breakfast
# 2             2           Breakfast
# 3             3           Breakfast
# 4             4           Breakfast
# ..          ...                 ...
# 255         255  Smoothies & Shakes
# 256         256  Smoothies & Shakes
# 257         257  Smoothies & Shakes
# 258         258  Smoothies & Shakes
# 259         259  Smoothies & Shakes
#
#                                                   Item     Serving Size  \
# 0                                         Egg McMuffin   4.8 oz (136 g)
# 1                                    Egg White Delight   4.8 oz (135 g)
# 2                                     Sausage McMuffin   3.9 oz (111 g)
# 3                            Sausage McMuffin with Egg   5.7 oz (161 g)
# 4                     Sausage McMuffin with Egg Whites   5.7 oz (161 g)
# ..                                                 ...              ...
# ...

# %% [markdown]
# We geven de head weer van het DataFrame.

# %%
df.head()
# Out:
#    Unnamed: 0   Category                              Item    Serving Size  \
# 0           0  Breakfast                      Egg McMuffin  4.8 oz (136 g)
# 1           1  Breakfast                 Egg White Delight  4.8 oz (135 g)
# 2           2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)
# 3           3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)
# 4           4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)
#
#    Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 0     300.0                120       13.0                         20
# 1     250.0                 70        8.0                         12
# 2     370.0                200       23.0                         35
# 3     450.0                250       28.0                         43
# 4     400.0                210       23.0                         35
#
#    Saturated Fat  Saturated Fat (% Daily Value)  ...  Carbohydrates  \
# ...

# %% [markdown]
# We maken een barchart met Items op de horizontale as en Total Fat op de verticale as.

# %%
df_plot = df.plot.bar(x='Item', y='Total Fat', figsize=(20, 10))
# plot_menu = mc_menu.plot(mc_menu["Item"], kind="bar")
df_plot
# Out:
# <AxesSubplot:xlabel='Item'>

# %% [markdown]
# De barchart van stap 3 is niet te lezen, dus maak nog een barchart met dezelfde voorwaarden, alleen gebruik nu enkel producten van de categorie "Smoothies & Shakes".

# %%
df_cat = df[(df["Category"] == "Smoothies & Shakes")]
df_cat
# Out:
#      Unnamed: 0            Category  \
# 232         232  Smoothies & Shakes
# 233         233  Smoothies & Shakes
# 234         234  Smoothies & Shakes
# 235         235  Smoothies & Shakes
# 236         236  Smoothies & Shakes
# 237         237  Smoothies & Shakes
# 238         238  Smoothies & Shakes
# 239         239  Smoothies & Shakes
# 240         240  Smoothies & Shakes
# 241         241  Smoothies & Shakes
# 242         242  Smoothies & Shakes
# 243         243  Smoothies & Shakes
# 244         244  Smoothies & Shakes
# 245         245  Smoothies & Shakes
# 246         246  Smoothies & Shakes
# 247         247  Smoothies & Shakes
# 248         248  Smoothies & Shakes
# 249         249  Smoothies & Shakes
# 250         250  Smoothies & Shakes
# 251         251  Smoothies & Shakes
# 252         252  Smoothies & Shakes
# 253         253  Smoothies & Shakes
# 254         254  Smoothies & Shakes
# 255         255  Smoothies & Shakes
# 256         256  Smoothies & Shakes
# ...

# %% [markdown]
# We plotten categorie "Smoothies & Shakes".

# %%
df_plot_cat = df_cat.plot.bar(x='Item', y='Total Fat', figsize=(20, 10))
df_plot_cat
# Out:
# <AxesSubplot:xlabel='Item'>

# %% [markdown]
# De volgende Items hebben een negatieve Total Fat waarde:
# - Vanilla Shake (Small)
# - Vanilla Shake (Medium)
# - Vanilla Shake (Large)
# - Strawberry Shake (Small)
# - Strawberry Shake (Medium)
# - Strawberry Shake (Large)
# - Chocolate Shake (Small)
# - Chocolate Shake (Medium)
# - Chocolate Shake (Large)

# %% [markdown]
# We maken een barchart met alle producten uit de categorie Chicken & Fish, en zet Items op de x-as en Calories op de y-as.

# %%
df_cat2 = df[(df["Category"] == "Chicken & Fish")]
df_cat2
# Out:
#     Unnamed: 0        Category  \
# 57          57  Chicken & Fish
# 58          58  Chicken & Fish
# 59          59  Chicken & Fish
# 60          60  Chicken & Fish
# 61          61  Chicken & Fish
# 62          62  Chicken & Fish
# 63          63  Chicken & Fish
# 64          64  Chicken & Fish
# 65          65  Chicken & Fish
# 66          66  Chicken & Fish
# 67          67  Chicken & Fish
# 68          68  Chicken & Fish
# 69          69  Chicken & Fish
# 70          70  Chicken & Fish
# 71          71  Chicken & Fish
# 72          72  Chicken & Fish
# 73          73  Chicken & Fish
# 74          74  Chicken & Fish
# 75          75  Chicken & Fish
# 76          76  Chicken & Fish
# 77          77  Chicken & Fish
# 78          78  Chicken & Fish
# 79          79  Chicken & Fish
# 80          80  Chicken & Fish
# 81          81  Chicken & Fish
# 82          82  Chicken & Fish
# 83          83  Chicken & Fish
#
# ...

# %% [markdown]
# We plotten categorie "Chicken & Fish".

# %%
df_plot_cat2 = df_cat2.plot.bar(x='Item', y='Calories', figsize=(20, 10))
df_plot_cat2
# Out:
# <AxesSubplot:xlabel='Item'>

# %% [markdown]
# We printen alle hoeveelheden calorieën uit de categorie Chicken & Fish om te kijken wat het aantal calorieën is van de wraps waar je geen balkje kunt zien.

# %%
df_na = df_cat2[df_cat2['Calories'].isna()]
df_na
# Out:
#     Unnamed: 0        Category  \
# 70          70  Chicken & Fish
# 71          71  Chicken & Fish
# 72          72  Chicken & Fish
# 73          73  Chicken & Fish
# 74          74  Chicken & Fish
# 75          75  Chicken & Fish
# 76          76  Chicken & Fish
# 77          77  Chicken & Fish
#
#                                                  Item     Serving Size  \
# 70    Premium McWrap Chicken & Bacon (Crispy Chicken)  11.1 oz (316 g)
# 71   Premium McWrap Chicken & Bacon (Grilled Chicken)  10.7 oz (302 g)
# 72    Premium McWrap Chicken & Ranch (Crispy Chicken)  10.9 oz (310 g)
# 73   Premium McWrap Chicken & Ranch (Grilled Chicken)  10.5 oz (297 g)
# 74  Premium McWrap Southwest Chicken (Crispy Chicken)  11.1 oz (314 g)
# 75  Premium McWrap Southwest Chicken (Grilled Chic...  11.2 oz (318 g)
# 76  Premium McWrap Chicken Sweet Chili (Crispy Chi...  10.7 oz (304 g)
# 77  Premium McWrap Chicken Sweet Chili (Grilled Ch...  10.3 oz (291 g)
#
# ...

# %% [markdown]
# We printen een nieuwe dataset zonder items met NaN.

# %%
df_new_cat2 = df_cat2.dropna()
df_new_cat2
# Out:
#     Unnamed: 0        Category                                        Item  \
# 57          57  Chicken & Fish     Premium Crispy Chicken Classic Sandwich
# 58          58  Chicken & Fish    Premium Grilled Chicken Classic Sandwich
# 59          59  Chicken & Fish        Premium Crispy Chicken Club Sandwich
# 60          60  Chicken & Fish       Premium Grilled Chicken Club Sandwich
# 61          61  Chicken & Fish   Premium Crispy Chicken Ranch BLT Sandwich
# 62          62  Chicken & Fish  Premium Grilled Chicken Ranch BLT Sandwich
# 63          63  Chicken & Fish     Bacon Clubhouse Crispy Chicken Sandwich
# 64          64  Chicken & Fish    Bacon Clubhouse Grilled Chicken Sandwich
# 65          65  Chicken & Fish      Southern Style Crispy Chicken Sandwich
# 66          66  Chicken & Fish                                   McChicken
# 67          67  Chicken & Fish                     Bacon Cheddar McChicken
# ...

# %% [markdown]
# We plotten een nieuwe barchart zonder items met NaN.

# %%
df_new_plot_cat2 = df_new_cat2.plot.bar(x='Item', y='Calories', figsize=(20, 10))
df_new_plot_cat2
# Out:
# <AxesSubplot:xlabel='Item'>
